# %%
import pandas as pd

# %%
dataset=pd.read_csv('t20_bbb.csv')
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_23132\1090454797.py:1: DtypeWarning: Columns (51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv('t20_bbb.csv')

# %%
dataset.columns
# Out:
# Index(['p_match', 'inns', 'bat', 'p_bat', 'team_bat', 'bowl', 'p_bowl',
#        'team_bowl', 'ball', 'ball_id', 'outcome', 'score', 'out', 'dismissal',
#        'p_out', 'over', 'noball', 'wide', 'byes', 'legbyes', 'cur_bat_runs',
#        'cur_bat_bf', 'cur_bowl_ovr', 'cur_bowl_wkts', 'cur_bowl_runs',
#        'inns_runs', 'inns_wkts', 'inns_balls', 'inns_runs_rem',
#        'inns_balls_rem', 'inns_rr', 'inns_rrr', 'target', 'max_balls', 'date',
#        'year', 'ground', 'country', 'winner', 'toss', 'competition',
#        'bat_hand', 'bowl_style', 'bowl_kind', 'batruns', 'ballfaced',
#        'bowlruns', 'bat_out', 'wagonX', 'wagonY', 'wagonZone', 'line',
#        'length', 'shot', 'control', 'predscore', 'wprob'],
#       dtype='object')

# %%
comparison=dataset[(dataset['competition']=='IPL') & (dataset['year']>=2018) & (dataset['bat_hand']=='RHB')]

# %%
comparison
# Out:
#          p_match  inns            bat    p_bat          team_bat  \
# 305      1175364     2       KL Rahul   422108      Punjab Kings
# 306      1175364     2       KL Rahul   422108      Punjab Kings
# 307      1175364     2       KL Rahul   422108      Punjab Kings
# 308      1175364     2       KL Rahul   422108      Punjab Kings
# 309      1175364     2       KL Rahul   422108      Punjab Kings
# ...          ...   ...            ...      ...               ...
# 1677732  1426311     2  Rovman Powell   820351  Rajasthan Royals
# 1677733  1426311     2  Rovman Powell   820351  Rajasthan Royals
# 1677734  1426311     2  Rovman Powell   820351  Rajasthan Royals
# 1677735  1426311     2    Dhruv Jurel  1175488  Rajasthan Royals
# 1677736  1426311     2    Dhruv Jurel  1175488  Rajasthan Royals
#
#                     bowl   p_bowl            team_bowl  ball  ball_id  ...  \
# 305       Lasith Malinga    49758       Mumbai Indians     1     1.01  ...
# ...

# %%
comparison['bowl_style'].value_counts()
# Out:
# RF          12162
# RM          10177
# LBG          8037
# RFM          7530
# SLA          7053
# OB           6081
# RMF          4201
# LFM          3898
# LB           3773
# LMF          3409
# LM           2854
# LWS          1316
# LF            701
# SLA/LWS       189
# OB/LB         172
# RM/OB/LB       21
# OB/LBG         11
# RM/OB          10
# Name: bowl_style, dtype: int64
