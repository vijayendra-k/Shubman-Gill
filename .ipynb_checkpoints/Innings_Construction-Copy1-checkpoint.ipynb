# %%
import pandas as pd

# %%
dataset=pd.read_csv('filtered_SG.csv')

# %%
# dataset.drop(columns=['Unnamed: 0'],inplace=True)

# %%
dataset['date']=pd.to_datetime(dataset['date'])

# %%
dataset=dataset.sort_values(by=['date','ball_id'])

# %%
dataset.groupby(['date','over','ball']).cumsum()
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_28472\1501107121.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby(['date','over','ball']).cumsum()
#       1s  2s  3s  4s  5s  6s  ball_id  balls  bowler_dismissed?  control  \
# 675    0   0   0   0   0   0    13.05      1                  0        1
# 789    0   0   0   0   0   0    13.06      1                  0        0
# 2215   1   0   0   0   0   0    14.05      1                  0        1
# 1761   1   0   0   0   0   0    15.02      1                  0        1
# 562    0   0   0   0   0   0    15.04      1                  0        1
# ...   ..  ..  ..  ..  ..  ..      ...    ...                ...      ...
# 1925   1   0   0   0   0   0    16.03      1                  0        1
# 2233   1   0   0   0   0   0    16.05      1                  0        1
# 1590   1   0   0   0   0   0    17.01      1                  0        1
# 2069   1   0   0   0   0   0    17.04      1                  0        1
# 802    0   0   0   0   0   0    17.06      1                  1        0
#
#       dots  Index  inns  inns_number  noball  outs  runs  wide  year
# 675      1      0     1            1       0     0     0     0  2018
# 789      1      1     1            1       0     0     0     0  2018
# 2215     0      2     1            1       0     0     1     0  2018
# 1761     0      3     1            1       0     0     1     0  2018
# 562      1      4     1            1       0     0     0     0  2018
# ...    ...    ...   ...          ...     ...   ...   ...   ...   ...
# 1925     0   2429     1            1       0     0     1     0  2024
# 2233     0   2430     1            1       0     0     1     0  2024
# 1590     0   2431     1            1       0     0     1     0  2024
# 2069     0   2432     1            1       0     0     1     0  2024
# 802      1   2433     1            1       0     1     0     0  2024
#
# [2434 rows x 19 columns]

# %%
numeric_cols=dataset.groupby(['date'])['runs','balls','outs','dots','1s','2s','3s','4s','5s','6s','control'].cumsum()
nonnumeric_cols=dataset[['date','team','inns_number','opposition','ground','dismissal']]
# Out:
# C:\Users\Vijay\AppData\Local\Temp\ipykernel_28472\3703232610.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   numeric_cols=dataset.groupby(['date'])['runs','balls','outs','dots','1s','2s','3s','4s','5s','6s','control'].cumsum()

# %%
cumulativedataset=pd.concat([nonnumeric_cols,numeric_cols],axis=1)

# %%
cumulativedataset
# Out:
#            date                   team  inns_number           opposition  \
# 675  2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 789  2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 2215 2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 1761 2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 562  2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# ...         ...                    ...          ...                  ...
# 1925 2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 2233 2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 1590 2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 2069 2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 802  2024-05-10         Gujarat Titans            1  Chennai Super Kings
#
#                                 ground dismissal  runs  balls  outs  dots  1s  \
# 675              Eden Gardens, Kolkata       NaN     0      1     0     1   0
# 789              Eden Gardens, Kolkata       NaN     0      2     0     2   0
# 2215             Eden Gardens, Kolkata       NaN     1      3     0     2   1
# 1761             Eden Gardens, Kolkata       NaN     2      4     0     2   2
# 562              Eden Gardens, Kolkata       NaN     2      5     0     3   2
# ...                                ...       ...   ...    ...   ...   ...  ..
# 1925  Narendra Modi Stadium, Ahmedabad       NaN   101     51     0    10  23
# 2233  Narendra Modi Stadium, Ahmedabad       NaN   102     52     0    10  24
# 1590  Narendra Modi Stadium, Ahmedabad       NaN   103     53     0    10  25
# 2069  Narendra Modi Stadium, Ahmedabad       NaN   104     54     0    10  26
# 802   Narendra Modi Stadium, Ahmedabad    caught   104     55     1    11  26
#
#       2s  3s  4s  5s  6s  control
# 675    0   0   0   0   0        1
# 789    0   0   0   0   0        1
# 2215   0   0   0   0   0        2
# 1761   0   0   0   0   0        3
# 562    0   0   0   0   0        4
# ...   ..  ..  ..  ..  ..      ...
# 1925   3   0   9   0   6       42
# 2233   3   0   9   0   6       43
# 1590   3   0   9   0   6       44
# 2069   3   0   9   0   6       45
# 802    3   0   9   0   6       45
#
# [2434 rows x 17 columns]

# %%
cumulativedataset['SR']=round(cumulativedataset['runs']*100/cumulativedataset['balls'],2)
cumulativedataset['Control%']=round(cumulativedataset['control']*100/cumulativedataset['balls'],2)
cumulativedataset.drop(['control'],axis=1,inplace=True)

# %%
transformdataset=cumulativedataset[['date','team','inns_number','opposition','ground','runs','balls','outs']]

# %%
transformdataset.set_index(['balls'],inplace=True)
transformdataset
# Out:
#             date                   team  inns_number           opposition  \
# balls
# 1     2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 2     2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 3     2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 4     2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# 5     2018-04-14  Kolkata Knight Riders            1  Sunrisers Hyderabad
# ...          ...                    ...          ...                  ...
# 51    2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 52    2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 53    2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 54    2024-05-10         Gujarat Titans            1  Chennai Super Kings
# 55    2024-05-10         Gujarat Titans            1  Chennai Super Kings
#
#                                  ground  runs  outs
# balls
# 1                 Eden Gardens, Kolkata     0     0
# 2                 Eden Gardens, Kolkata     0     0
# 3                 Eden Gardens, Kolkata     1     0
# 4                 Eden Gardens, Kolkata     2     0
# 5                 Eden Gardens, Kolkata     2     0
# ...                                 ...   ...   ...
# 51     Narendra Modi Stadium, Ahmedabad   101     0
# 52     Narendra Modi Stadium, Ahmedabad   102     0
# 53     Narendra Modi Stadium, Ahmedabad   103     0
# 54     Narendra Modi Stadium, Ahmedabad   104     0
# 55     Narendra Modi Stadium, Ahmedabad   104     1
#
# [2434 rows x 7 columns]

# %%
transformdataset=transformdataset.T
transformdataset
# Out:
# balls                           1                      2   \
# date           2018-04-14 00:00:00    2018-04-14 00:00:00
# team         Kolkata Knight Riders  Kolkata Knight Riders
# inns_number                      1                      1
# opposition     Sunrisers Hyderabad    Sunrisers Hyderabad
# ground       Eden Gardens, Kolkata  Eden Gardens, Kolkata
# runs                             0                      0
# outs                             0                      0
#
# balls                           3                      4   \
# date           2018-04-14 00:00:00    2018-04-14 00:00:00
# team         Kolkata Knight Riders  Kolkata Knight Riders
# inns_number                      1                      1
# opposition     Sunrisers Hyderabad    Sunrisers Hyderabad
# ground       Eden Gardens, Kolkata  Eden Gardens, Kolkata
# runs                             1                      2
# outs                             0                      0
#
# balls                           5                      6   \
# date           2018-04-14 00:00:00    2018-04-14 00:00:00
# team         Kolkata Knight Riders  Kolkata Knight Riders
# inns_number                      1                      1
# opposition     Sunrisers Hyderabad    Sunrisers Hyderabad
# ground       Eden Gardens, Kolkata  Eden Gardens, Kolkata
# runs                             2                      3
# outs                             0                      0
#
# balls                           7                      8   \
# date           2018-04-14 00:00:00    2018-04-14 00:00:00
# team         Kolkata Knight Riders  Kolkata Knight Riders
# inns_number                      1                      1
# opposition     Sunrisers Hyderabad    Sunrisers Hyderabad
# ground       Eden Gardens, Kolkata  Eden Gardens, Kolkata
# runs                             3                      3
# outs                             0                      0
#
# balls                           9                      1   ...  \
# date           2018-04-14 00:00:00    2018-04-16 00:00:00  ...
# team         Kolkata Knight Riders  Kolkata Knight Riders  ...
# inns_number                      1                      1  ...
# opposition     Sunrisers Hyderabad         Delhi Capitals  ...
# ground       Eden Gardens, Kolkata  Eden Gardens, Kolkata  ...
# runs                             3                      4  ...
# outs                             1                      0  ...
#
# balls                                      46  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                       95
# outs                                        0
#
# balls                                      47  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                       96
# outs                                        0
#
# balls                                      48  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                       96
# outs                                        0
#
# balls                                      49  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                       96
# outs                                        0
#
# balls                                      50  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      100
# outs                                        0
#
# balls                                      51  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      101
# outs                                        0
#
# balls                                      52  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      102
# outs                                        0
#
# balls                                      53  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      103
# outs                                        0
#
# balls                                      54  \
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      104
# outs                                        0
#
# balls                                      55
# date                      2024-05-10 00:00:00
# team                           Gujarat Titans
# inns_number                                 1
# opposition                Chennai Super Kings
# ground       Narendra Modi Stadium, Ahmedabad
# runs                                      104
# outs                                        1
#
# [7 rows x 2434 columns]

# %%
grouped_df = cumulativedataset.groupby(['date','team','inns_number','opposition','ground','balls'])['runs'].sum()
grouped_df
# Out:
# date        team                   inns_number  opposition           ground                            balls
# 2018-04-14  Kolkata Knight Riders  1            Sunrisers Hyderabad  Eden Gardens, Kolkata             1          0
#                                                                                                        2          0
#                                                                                                        3          1
#                                                                                                        4          2
#                                                                                                        5          2
#                                                                                                                ...
# 2024-05-10  Gujarat Titans         1            Chennai Super Kings  Narendra Modi Stadium, Ahmedabad  51       101
#                                                                                                        52       102
#                                                                                                        53       103
#                                                                                                        54       104
#                                                                                                        55       104
# Name: runs, Length: 2373, dtype: int64

# %%
pivot_df = grouped_df.pivot(index='date', columns='balls', values='runs')
pivot_df = pivot_df.reindex(sorted(pivot_df.columns), axis=1)
pivot_df

# %%
grouped_df.tail(56
            )

# %%
cumulativedataset.to_csv('ans.csv')
